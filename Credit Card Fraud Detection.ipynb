# %% [markdown]
# ## Credit Card Fraud detection model Using Logistic Regression and SVClassifier

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('./creditcard.csv')

# %% [markdown]
# ### Analysis of Dataset

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
plt.hist(df['Time'])
plt.show()

# %%
plt.hist(df['Amount'])
plt.show()

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %% [markdown]
# ### Data Preprocessing

# %%
from sklearn.preprocessing import StandardScaler

# %%
df['Amount']=StandardScaler().fit_transform(df['Amount'].to_numpy().reshape(-1,1))
df['Time']=StandardScaler().fit_transform(df['Time'].to_numpy().reshape(-1,1))

# %%
df.head(10)
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0 -1.996583 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1 -1.996583  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2 -1.996562 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3 -1.996562 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4 -1.996541 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# 5 -1.996541 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728
# 6 -1.996499  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708
# 7 -1.996436 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118
# 8 -1.996436 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818
# 9 -1.996394 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928
# ...

# %%
df.describe()
# Out:
#                Time            V1            V2            V3            V4  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -3.065637e-16  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std    1.000002e+00  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min   -1.996583e+00 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%   -8.552120e-01 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%   -2.131453e-01  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    9.372174e-01  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    1.642058e+00  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
frauds=df.query('Class==1')
legits=df.query('Class==0')

# %%
frauds.head()
# Out:
#           Time        V1        V2        V3        V4        V5        V6  \
# 541  -1.988034 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623  -1.986644 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920 -1.902623 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108 -1.849472 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329 -1.838248  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 541  -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623   0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
# 4920  0.562320 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726
# 6108 -3.496197 -0.248778 -0.247768  ...  0.573574  0.176968 -0.436207
# 6329  1.713445 -0.496358 -1.282858  ... -0.379068 -0.704181 -0.656805
#
#            V24       V25       V26       V27       V28    Amount  Class
# ...

# %%
frauds['Class'].value_counts()
# Out:
# 1    492
# Name: Class, dtype: int64

# %%
legits['Class'].value_counts()
# Out:
# 0    284315
# Name: Class, dtype: int64

# %%
balancedDf=pd.concat([frauds,legits.sample(len(frauds),random_state=123)])

# %%
balancedDf
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541    -1.988034 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    -1.986644 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920   -1.902623 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108   -1.849472 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329   -1.838248  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 144465 -0.182548  1.003419 -1.462467  0.508759 -0.622205 -1.452351  0.036928
# 193773  0.746885 -1.956324  1.089627 -2.026201  1.077582 -0.273602 -0.517162
# 65113  -0.913490 -0.705168  1.050057  1.308228  0.872214 -0.378911  0.359449
# 132619 -0.310812  1.410737 -0.879178 -1.114539 -1.614882  1.401257  3.447835
# 100865 -0.572036 -1.087124  0.356939  2.520573  0.145459  0.428279 -0.619265
#
# ...

# %%
balancedDf['Class'].value_counts()
# Out:
# 1    492
# 0    492
# Name: Class, dtype: int64

# %%
balancedDf=balancedDf.sample(frac=1,random_state=123)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

# %%
newdf=balancedDf.copy()

# %%
newdf.shape
# Out:
# (984, 31)

# %%
newdf.head()
# Out:
#             Time        V1        V2         V3        V4        V5        V6  \
# 150663 -0.020234 -5.839192  7.151532 -12.816760  7.031115 -9.651272 -2.938427
# 18021  -1.383334 -0.481958  0.482840   1.273747 -1.191768  0.273348 -0.424986
# 156773  0.296520  2.209725 -0.957438  -0.772473 -0.816003 -0.644196 -0.020690
# 177910  0.601923  1.738467 -1.366104  -1.096767 -0.316220 -0.726390 -0.232783
# 74794  -0.822393 -6.003422 -3.930731  -0.007045  1.714669  3.414667 -2.329583
#
#                V7        V8        V9  ...       V21       V22       V23  \
# 150663 -11.543207  4.843627 -3.494276  ...  2.462056  1.054865  0.530481
# 18021    0.530699  0.138924 -0.266036  ... -0.194091 -0.794606  0.062640
# 156773  -1.188476 -0.058351  1.576077  ...  0.116254  0.583714  0.100130
# 177910  -0.325341 -0.240538 -0.421144  ... -0.227016 -0.468229  0.119926
# 74794   -1.901512 -2.746111  0.887673  ...  1.101671 -0.992494 -0.698259
#
# ...

# %%
X=newdf.drop(['Class'],axis=1)

# %%
X.head()
# Out:
#             Time        V1        V2         V3        V4        V5        V6  \
# 150663 -0.020234 -5.839192  7.151532 -12.816760  7.031115 -9.651272 -2.938427
# 18021  -1.383334 -0.481958  0.482840   1.273747 -1.191768  0.273348 -0.424986
# 156773  0.296520  2.209725 -0.957438  -0.772473 -0.816003 -0.644196 -0.020690
# 177910  0.601923  1.738467 -1.366104  -1.096767 -0.316220 -0.726390 -0.232783
# 74794  -0.822393 -6.003422 -3.930731  -0.007045  1.714669  3.414667 -2.329583
#
#                V7        V8        V9  ...       V20       V21       V22  \
# 150663 -11.543207  4.843627 -3.494276  ...  0.055684  2.462056  1.054865
# 18021    0.530699  0.138924 -0.266036  ... -0.102705 -0.194091 -0.794606
# 156773  -1.188476 -0.058351  1.576077  ... -0.058657  0.116254  0.583714
# 177910  -0.325341 -0.240538 -0.421144  ... -0.046711 -0.227016 -0.468229
# 74794   -1.901512 -2.746111  0.887673  ... -4.128186  1.101671 -0.992494
#
# ...

# %%
y=newdf['Class']

# %%
y.head()
# Out:
# 150663    1
# 18021     0
# 156773    0
# 177910    0
# 74794     1
# Name: Class, dtype: int64

# %%
train_X, test_X, train_y, test_y = train_test_split(X, y, random_state = 1)

# %%
logisticModel=LogisticRegression()

# %%
train_X.shape
# Out:
# (738, 30)

# %%
test_X.shape
# Out:
# (246, 30)

# %%
train_y.shape
# Out:
# (738,)

# %%
logisticModel.fit(train_X,train_y)
# Out:
# LogisticRegression()

# %%
logisticModel.score(train_X,train_y)
# Out:
# 0.948509485094851

# %%
print(classification_report(test_y,logisticModel.predict(test_X),target_names=['Legit','Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#        Legit       0.91      0.95      0.93       128
#        Fraud       0.94      0.90      0.92       118
#
#     accuracy                           0.92       246
#    macro avg       0.92      0.92      0.92       246
# weighted avg       0.92      0.92      0.92       246

# %%
SVclassifierModel=SVC()

# %%
SVclassifierModel.fit(train_X,train_y)
# Out:
# SVC()

# %%
print(classification_report(test_y,SVclassifierModel.predict(test_X),target_names=['Legit','Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#        Legit       0.88      0.97      0.92       128
#        Fraud       0.96      0.86      0.91       118
#
#     accuracy                           0.91       246
#    macro avg       0.92      0.91      0.91       246
# weighted avg       0.92      0.91      0.91       246

# %%
import joblib

# %%
filename = 'logisticmodel.sav'
joblib.dump(logisticModel, filename)
# Out:
# ['logisticmodel.sav']

# %%
filename = 'SVClassifierModel.sav'
joblib.dump(SVclassifierModel, filename)
# Out:
# ['SVClassifierModel.sav']
